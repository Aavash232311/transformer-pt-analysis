# %% [markdown]
# ### Report on the patterns that I have noticed.

# %% [markdown]
# We need to keep the balanace between `weight_decay` and `data_split` and learning rate, sequence length and so on.
#
#
# If we have more data in training then it will learn instead of overfitting.
#
# If we have more modulo then there will be more unique pairs, not the sequences.
#
#
#
# If the graph of loss in validation is sloping upward then it's going to explode and come back down, same pattern continues.
#
#
# If the nature of graph of loss in validation is downward sloping then god knows that happens.
